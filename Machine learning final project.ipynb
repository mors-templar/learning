# %%
import pandas as pd

# %%
df=pd.read_csv('C:\\Python crash course\\Datasets\\Property_with_Feature_Engineering Zameen.com.csv')

# %%
df
# Out:
#         property_id  location_id  \
# 0            347795            8
# 1            482892           48
# 2            555962           75
# 3            562843         3821
# 4            686990         3522
# ...             ...          ...
# 191388     17468383          174
# 191389     17468384          174
# 191390     17468482          167
# 191391     17468586          339
# 191392     17468660         3421
#
#                                                  page_url  property_type  \
# 0       https://www.zameen.com/Property/lahore_model_t...          House
# 1       https://www.zameen.com/Property/lahore_multan_...          House
# 2       https://www.zameen.com/Property/eden_eden_aven...          House
# 3       https://www.zameen.com/Property/gulberg_2_gulb...          House
# 4       https://www.zameen.com/Property/allama_iqbal_t...          House
# ...                                                   ...            ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191393 entries, 0 to 191392
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   property_id    191393 non-null  int64
#  1   location_id    191393 non-null  int64
#  2   page_url       191393 non-null  object
#  3   property_type  191393 non-null  object
#  4   price          191393 non-null  int64
#  5   price_bin      191393 non-null  object
#  6   location       191393 non-null  object
#  7   city           191393 non-null  object
#  8   province_name  191393 non-null  object
#  9   locality       191393 non-null  object
#  10  latitude       191393 non-null  float64
#  11  longitude      191393 non-null  float64
#  12  baths          191393 non-null  int64
#  13  area           191393 non-null  object
#  14  area_marla     191393 non-null  float64
#  15  area_sqft      191393 non-null  float64
#  16  purpose        191393 non-null  object
# ...

# %%
df.drop(['property_id','location_id','page_url','price_bin','location','city','province_name','locality','area','area_sqft','date_added','year','month','day','agency','agent','latitude','longitude'],inplace=True,axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191393 entries, 0 to 191392
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   property_type  191393 non-null  object
#  1   price          191393 non-null  int64
#  2   baths          191393 non-null  int64
#  3   area_marla     191393 non-null  float64
#  4   purpose        191393 non-null  object
#  5   bedrooms       191393 non-null  int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 8.8+ MB

# %%
df['purpose'].unique()
# Out:
# array(['For Sale', 'For Rent'], dtype=object)

# %%
df['property_type'].replace({'House':0, 'Flat':1, 'Lower Portion':2, 'Penthouse':3, 'Upper Portion':4,'Farm House':5, 'Room':6},inplace=True)

# %%
df['purpose'].replace({'For Sale':0, 'For Rent':1},inplace=True)

# %%
df
# Out:
#         property_type      price  baths  area_marla  purpose  bedrooms
# 0                   0  220000000      0       120.0        0         0
# 1                   0   40000000      5        20.0        0         5
# 2                   0    9500000      0         9.0        0         3
# 3                   0  125000000      7        20.0        0         8
# 4                   0   21000000      5        11.0        0         6
# ...               ...        ...    ...         ...      ...       ...
# 191388              4      70000      0        12.4        1         3
# 191389              4      40000      0        12.4        1         2
# 191390              0     160000      6        20.0        1         6
# 191391              1      25000      2         2.7        1         2
# 191392              4      26000      1         0.0        1         3
#
# [191393 rows x 6 columns]

# %%
x=df.drop('price',axis=1)
y=df['price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# %%
rf=RandomForestRegressor(n_estimators=50)

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=50)

# %%
rf_prediction=rf.predict(X_test)

# %%
mean_absolute_error(rf_prediction,y_test)
# Out:
# 5716501.373724685

# %%
import pickle

# %%
pickle.dump(rf,open('model_pricing.pkl','wb'))

# %%
model=pickle.load(open('model_pricing.pkl','rb'))

# %%
print(model.predict([[2,3,10,1,2]]))
# Out:
# [34869.08108275]
# C:\Users\Qasim\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
X_train.columns
# Out:
# Index(['property_type', 'baths', 'area_marla', 'purpose', 'bedrooms'], dtype='object')
